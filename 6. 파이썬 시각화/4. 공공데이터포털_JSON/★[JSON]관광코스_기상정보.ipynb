# %%
import requests
import json
key = '2hRG6CE9VwKPxbi%2BNiZ1EGvHaghzZFKwv0D8guJ8ieKVpdmq0NEVO8XLqI8iNOBeazs9Z0%2Fuc%2Bjq2FTWQ7bwww%3D%3D'
# decode_key = requests.utils.unquote(key)
                                 #서비스 url                                  상세 기능명
response = requests.get('http://apis.data.go.kr/1360000/TourStnInfoService/getTourStnVilageFcst\
# ?serviceKey={}\
&numOfRows=10&pageNo=1&dataType=JSON&CURRENT_DATE=2020080601&HOUR=24&COURSE_ID=1'.format(key))
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"courseAreaId":"4700000000","courseAreaName":"경상북도","courseId":"1","courseName":"남호고택에서의 하룻밤","pop":80,"rhm":95,"sky":5,"spotAreaId":102,"spotAreaName":"봉화","spotName":"(봉화)춘양목 송이마을","th3":20,"thema":"문화/예술","tm":"2020-08-08 00:00","wd":342,"ws":0},{"courseAreaId":"4700000000","courseAreaName":"경상북도","courseId":"1","courseName":"남호고택에서의 하룻밤","pop":80,"rhm":95,"sky":5,"spotAreaId":104,"spotAreaName":"봉화","spotName":"(봉화)계서당(성이성 생가)","th3":22,"thema":"종교/역사/전통","tm":"2020-08-08 00:00","wd":360,"ws":0},{"courseAreaId":"4700000000","courseAreaName":"경상북도","courseId":"1","courseName":"남호고택에서의 하룻밤","pop":80,"rhm":95,"sky":5,"spotAreaId":104,"spotAreaName":"봉화","spotName":"(봉화)계서당(성이성 생가)","th3":22,"thema":"자연/힐링","tm":"2020-08-08 00:00","wd":360,"ws":0},{"courseAreaId":"4700000000","courseAreaName":"경상북도","courseId":"1","courseName":"남호고택에서의 하룻밤","pop":80,"rhm":95,"sky":5,"sp
# ...

# %%
data=json.loads(response.text)
#데이터가 뽑혀온다 정도로 알기

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '1',
#       'courseName': '남호고택에서의 하룻밤',
#       'pop': 80,
#       'rhm': 95,
#       'sky': 5,
#       'spotAreaId': 102,
#       'spotAreaName': '봉화',
#       'spotName': '(봉화)춘양목 송이마을',
#       'th3': 20,
#       'thema': '문화/예술',
#       'tm': '2020-08-08 00:00',
#       'wd': 342,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '1',
#       'courseName': '남호고택에서의 하룻밤',
#       'pop': 80,
#       'rhm': 95,
#       'sky': 5,
#       'spotAreaId': 104,
#       'spotAreaName': '봉화',
#       'spotName': '(봉화)계서당(성이성 생가)',
#       'th3': 22,
#       'thema': '종교/역사/전통',
#       'tm': '2020-08-08 00:00',
#       'wd': 360,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
# ...

# %%
a = data['response']['body']['items']['item']

print(len(a))
a
# Out:
# 10
# [{'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '1',
#   'courseName': '남호고택에서의 하룻밤',
#   'pop': 80,
#   'rhm': 95,
#   'sky': 5,
#   'spotAreaId': 102,
#   'spotAreaName': '봉화',
#   'spotName': '(봉화)춘양목 송이마을',
#   'th3': 20,
#   'thema': '문화/예술',
#   'tm': '2020-08-08 00:00',
#   'wd': 342,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '1',
#   'courseName': '남호고택에서의 하룻밤',
#   'pop': 80,
#   'rhm': 95,
#   'sky': 5,
#   'spotAreaId': 104,
#   'spotAreaName': '봉화',
#   'spotName': '(봉화)계서당(성이성 생가)',
#   'th3': 22,
#   'thema': '종교/역사/전통',
#   'tm': '2020-08-08 00:00',
#   'wd': 360,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '1',
#   'courseName': '남호고택에서의 하룻밤',
#   'pop': 80,
#   'rhm': 95,
#   'sky': 5,
#   'spotAreaId': 104,
#   'spotAreaName': '봉화',
#   'spotName': '(봉화)계서당(성이성 생가)',
#   'th3': 22,
#   'thema': '자연/힐링',
# ...

# %%
a
# Out:
# [{'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '1',
#   'courseName': '남호고택에서의 하룻밤',
#   'pop': 80,
#   'rhm': 95,
#   'sky': 5,
#   'spotAreaId': 102,
#   'spotAreaName': '봉화',
#   'spotName': '(봉화)춘양목 송이마을',
#   'th3': 20,
#   'thema': '문화/예술',
#   'tm': '2020-08-08 00:00',
#   'wd': 342,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '1',
#   'courseName': '남호고택에서의 하룻밤',
#   'pop': 80,
#   'rhm': 95,
#   'sky': 5,
#   'spotAreaId': 104,
#   'spotAreaName': '봉화',
#   'spotName': '(봉화)계서당(성이성 생가)',
#   'th3': 22,
#   'thema': '종교/역사/전통',
#   'tm': '2020-08-08 00:00',
#   'wd': 360,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '1',
#   'courseName': '남호고택에서의 하룻밤',
#   'pop': 80,
#   'rhm': 95,
#   'sky': 5,
#   'spotAreaId': 104,
#   'spotAreaName': '봉화',
#   'spotName': '(봉화)계서당(성이성 생가)',
#   'th3': 22,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
# ...
