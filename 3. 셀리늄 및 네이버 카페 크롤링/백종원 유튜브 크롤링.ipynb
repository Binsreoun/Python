# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.youtube.com/channel/UCyn-K7rZLXjGl7VXGweIlcA/videos'
driver.get(url)

# %%
import time
SCROLL_PAUSE_TIME = 0.5
# 한번 스크롤 하고 멈출 시간 설정

body = driver.find_element_by_tag_name('body')
# body태그를 선택하여 body에 넣음

while True:
    last_height = driver.execute_script('return document.documentElement.scrollHeight')
    # 현재 화면의 길이를 리턴 받아 last_height에 넣음
    for i in range(10):
        body.send_keys(Keys.END)
        # body 본문에 END키를 입력(스크롤내림)
        time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.documentElement.scrollHeight')
    if new_height == last_height:
        break;

# %%
from bs4 import BeautifulSoup

page = driver.page_source
soup = BeautifulSoup(page, 'lxml')

# %%
all_videos = soup.find_all(id='dismissable')

title_list = []
for video in all_videos:
    title = video.find(id='video-title')
    if len(title.text.strip())>0:
        title_list.append(title.text)
    # 공백을 제거하고 글자수가 0보다 크면 append    

print(title_list)
print(len(title_list))
# Out:
# ['라면으로 만드는 비빔면 Bibimmyun Made From Ramyun', "초간단 '고추기름' 만들기!", "뽀오얀 국물이 제대로~ 더위 나기 보양식 '닭곰탕'", '이런 카레가 있었어?', '고기와 싸먹으면 정~말 맛있는 파프리카 무침! 입안에서 톡!! Bursts in Your Mouth! Paprika Muchim', '미역냉국 만들다가 국수가 땡겨 만든 냉국수! Ice-Cold Naengguk, Perfect for the Summer! It Makes You Crave Noodles!', '옥수수 캔으로 만드는 최고의 간식 The Ultimate Snack Made from Canned Corn', '김치전을 바삭바삭하게!', '집에 손님 올 때는 이 메뉴를 해보세요. Make This Dish When You Have Guests Over!', '식당에서 먹는 닭볶음탕의 비법은 바로~ What is the secret of Dak-bokkeum-tang in a restaurant?', "장 보러 '서울중앙시장'에 다녀왔습니다! I Went to Seoul Central Market for Grocery Shopping!", '얼큰하고 매콤하게~ 밥도둑 두부조림! Hot and spicy dubujorim!', "비빔국수 만들다가 신메뉴가 탄생했습니다 '○○비빔국수' !! The Season for Bibim Guksu! Check Out This New Kind of Guksu.", '시골에서 먹는 강된장! 밥에 비벼 먹으면 끝이에요! Good Old Country Food, Gangdoenjang! Just Mix It With Rice!', '자연스러운 감칠맛의 다시마칼국수! Naturally flavorful dasima kalguksu!', '폭신~폭신한 에그 샌드위치 Soft and fluffy egg sandwich', '밖에서 사먹는 순두부찌개 맛을 집에서!! Sundubu Jjigae!, No Need to Make a Sauce Separately!', "식당에서 나오는 바로 그 '콘치즈'! Corn Cheese! A Dish of Peculiar Charm", '오트밀도 이제 맛있는 음식 입니다. (K 오트밀)', '진짜 Real!? 고구마를 넣은 고구마피자! Is it true? Sweet potato pizza with real sweet potato!', '식당에서 파는 그 닭고기 덮밥 Chicken Deopbap that is served at Restaurants!', "열무와 돼지고기를 된장으로 치치지직! 볶아내어 밥 위에 턱! 올려놓고 입안에 넣으면 아삭! 아삭! 으으으음!! 벌써 다 먹었네 '열무된장 양념덮밥'", '[Sub] 냉동만두 + 달걀말이 = 일품요리', '[Sub] 정말 쉬운 달걀말이!', "
떡 볶 이🎉', '얼큰한 고추장찌개! 밥 한 공기 뚝딱! l 백종원의 백종원레시피', '햄버거 패티가 바삭 바삭! 돼지마늘버거입니다. ㅣ 백종원의 쿠킹로그', '부먹, 찍먹 다 맛있는 탕수육! 바삭 바삭~ ㅣ 백종원의 쿠킹로그', '참~쉬운 찜닭! 집에서 이건 꼭 한번 해보세요. ㅣ 백종원의 백종원레시피', '고기짬뽕라면 1인분 만들기 (feat.맛남의광장) ㅣ 백종원의 쿠킹로그', '삼색나물 마지막 고사리나물 ^^. 새해 복 많이 받으세요 ! ㅣ 백종원의 백종원레시피', '올 한해도 떡만둣국 드시고 대박 나세요!! ㅣ 백종원의 쿠킹로그', '설날 준비! 삼색 나물 두 번째 도라지 나물입니다. ㅣ 백종원의 백종원레시피', '설날 준비 LA갈비! ㅣ 백종원의 쿠킹로그', '설 준비하셔야죠? 삼색 나물 첫 번째 시금치나물입니다 ㅣ 백종원의 백종원레시피', "'호불호 강한 홍어! 불호 손님은 어떻게??' ㅣ 백종원의 장사이야기", '중화제육면 1인분 만들기 ㅣ 백종원의 쿠킹로그', "떡갈비 버거, 일명 '붹붹버거'입니다! 햄버거는 한식이죠~~?? l 백종원의 쿠킹로그", '감사합니다! Thank you!', "'맛남의 광장' 막내 동준님과 함께 만드는 편육냉채! 응용 버전도 확인해보세요! ㅣ 백종원의 쿠킹로그", "'부대찌개, 탕, 국수 메뉴의 문제가 뭔지 아세요?'  | 백종원의 장사이야기", '비 오는 날엔 술 한잔 생각나는 김치찜! 고등어 통조림으로 쉽게 만듭니다! ㅣ 백종원의 백종원레시피', '눈오는 쌀쌀한 날씨엔 어묵전골! 따듯한 국물에 ㅋ ㅑ~~ㅣ 백종원의 쿠킹로그', "'간단명료 해야 돼요, 분석이 너무 심하면 안 돼요' ㅣ 백종원의 장사이야기", '★고추마늘치킨★ 충격! 백스비어 영업기밀 공개!ㅣ 백종원의 쿠킹로그', '고기만두!! 비법이 들어 있습니다. 가족과 함께 집에서 만들어 보세요!!  ㅣ 백종원의 쿠킹로그', "서른일곱 번째 '백종원의 장사이야기'를 진행합니다!", "'내가 가격 낮추면 되지 덜 남으면 좀 어때!' ㅣ 백종원의 장사이야기", '홍합으로 시원한 홍합탕을 만들어 드셔보세요~~~!! l 백종원의 백종원레시피', "메리 크리스마스! '함박스테이크'로 우아한 크리스마스 보내세요~ l 백종원의 쿠킹로그", "초대손님 '양 ...
# 212

# %%
video_time_list = []
for video in all_videos:
    video_time = video.find('span',{'class' : 'style-scope ytd-thumbnail-overlay-time-status-renderer'})
    video_time_list.append(video_time.text.strip())

print(video_time_list)    
print(len(video_time_list))
# Out:
# ['10:06', '5:08', '11:08', '9:53', '12:21', '12:30', '9:34', '10:55', '13:41', '18:44', '6:33', '8:40', '7:31', '14:09', '12:23', '8:58', '11:42', '10:47', '16:14', '10:21', '8:21', '13:18', '6:12', '7:52', '8:50', '11:22', '9:19', '17:04', '12:44', '5:42', '13:18', '15:43', '10:04', '10:40', '12:06', '11:20', '16:58', '15:10', '11:53', '14:
# %%
import re

view_num_list = []
view_num_regexp = re.compile(r'조회수')
for video in all_videos:
    view_num = video.find('span',{'class':'style-scope ytd-grid-video-renderer'})
    if view_num_regexp.search(view_num.text):
        # view_num.text 에 '조회수' 문자열이 있으면 True
        view_num_list.append(view_num.text)
view_num_list
# Out:
# ['조회수 55만회',
#  '조회수 25만회',
#  '조회수 50만회',
#  '조회수 34만회',
#  '조회수 26만회',
#  '조회수 50만회',
#  '조회수 47만회',
#  '조회수 151만회',
#  '조회수 46만회',
#  '조회수 99만회',
#  '조회수 25만회',
#  '조회수 70만회',
#  '조회수 125만회',
#  '조회수 48만회',
#  '조회수 29만회',
#  '조회수 79만회',
#  '조회수 56만회',
#  '조회수 123만회',
#  '조회수 67만회',
#  '조회수 40만회',
#  '조회수 48만회',
#  '조회수 25만회',
#  '조회수 42만회',
#  '조회수 27만회',
#  '조회수 80만회',
#  '조회수 28만회',
#  '조회수 90만회',
#  '조회수 184만회',
#  '조회수 66만회',
#  '조회수 29만회',
#  '조회수 24만회',
#  '조회수 55만회',
#  '조회수 59만회',
#  '조회수 143만회',
#  '조회수 41만회',
#  '조회수 34만회',
#  '조회수 203만회',
#  '조회수 41만회',
#  '조회수 167만회',
#  '조회수 74만회',
#  '조회수 196만회',
#  '조회수 103만회',
#  '조회수 122만회',
#  '조회수 31만회',
#  '조회수 53만회',
#  '조회수 61만회',
#  '조회수 29만회',
#  '조회수 144만회',
#  '조회수 63만회',
#  '조회수 187만회',
#  '조회수 20만회',
#  '조회수 319만회',
#  '조회수 31만회',
#  '조회수 19만회',
#  '조회수 191만회',
#  '조회수 51만회',
#  '조회수 45만회',
#  '조회수 179만회',
#  '조회수 31만회',
#  '조회수 123만회',
#  '조회수 146만회',
#  '조회수 35만회',
#  '조회수 56만회',
#  '조회수 239만회',
#  '조회수 78만회',
#  '조회수 86만회',
#  '조회수 66만회',
#  '조회수 229만회',
#  '조회수 82만회',
#  '조회수 124만회',
#  '조회수 105만회',
#  '조회수 15만회',
#  '조회수 132만회',
#  '조회수 62만회',
#  '조회수 41만회',
#  '조회수 51만회',
#  '조회수 24만회',
#  '조회수 51만회',
#  '조회수 50만회',
#  '조회수 504만회',
#  '조회수 124만회',
#  '조회수 54만회',
#  '조회수 100만회',
#  '조회수 134만회',
#  '조회수 175만회',
#  '조회수 19만회',
#  '조회수 89만회',
#  '조회수 20만회',
#  '조회수 119만회',
#  '조회수 52만회',
#  '조회수 10만회',
#  '조회수 182만회',
#  '조회수 53만회',
#  '조회수 157만회',
#  '조회수 46만회',
#  '조회수 26만회',
#  '조회수 49만회',
#  '조회수 93만회',
#  '조회수 18만회',
#  '조회수 169만회',
#  '조회수 109만회',
#  '조회수 7.3만회',
#  '조회수 30만회',
#  '조회수 40만회',
#  '조회수 98만회',
#  '조회수 483만회',
#  '조회수 186만회',
#  '조회수 100만회',
#  '조회수 123만회',
#  '조회수 40만회',
#  '조회수 105만회',
#  '조회수 347만회',
#  '조회수 90만회',
#  '조회수 23만회',
#  '조회수 143만회',
#  '조회수 56만회',
#  '조회수 529만회',
#  '조회수 199만회',
#  '조회수 94만회',
#  '조회수 17만회',
#  '조회수 88만회',
#  '조회수 80만회',
#  '조회수 17만회',
#  '조회수 72만회',
#  '조회수 124만회',
#  '조회수 183만회',
#  '조회수 179만회',
#  '조회수 137만회',
#  '조회수 547만회',
#  '조회수 38만회',
#  '조회수 472만회',
#  '조회수 40만회',
#  '조회수 33만회',
#  '조회수 147만회',
#  '조회수 530만회',
#  '조회수 229만회',
#  '조회수 36만회',
#  '조회수 80만회',
#  '조회수 115만회',
#  '조회수 111만회',
#  '조회수 22만회',
#  '조회수 76만회',
#  '조회수 234만회',
#  '조회수 34만회',
#  '조회수 56만회',
#  '조회수 55만회',
#  '조회수 209만회',
#  '조회수 48만회',
#  '조회수 233만회',
#  '조회수 30만회',
#  '조회수 185만회',
#  '조회수 200만회',
#  '조회수 182만회',
#  '조회수 22만회',
#  '조회수 71만회',
#  '조회수 350만회',
#  '조회수 132만회',
#  '조회수 65만회',
#  '조회수 22만회',
#  '조회수 111만회',
#  '조회수 383만회',
#  '조회수 176만회',
#  '조회수 81만회',
#  '조회수 58만회',
#  '조회수 73만회',
#  '조회수 11만회',
#  '조회수 232만회',
#  '조회수 109만회',
#  '조회수 93만회',
#  '조회수 333만회',
#  '조회수 233만회',
#  '조회수 33만회',
#  '조회수 208만회',
#  '조회수 113만회',
#  '조회수 66만회',
#  '조회수 309만회',
#  '조회수 411만회',
#  '조회수 80만회',
#  '조회수 263만회',
#  '조회수 59만회',
#  '조회수 97만회',
#  '조회수 57만회',
#  '조회수 225만회',
#  '조회수 609만회',
#  '조회수 136만회',
#  '조회수 282만회',
#  '조회수 193만회',
#  '조회수 103만회',
#  '조회수 93만회',
#  '조회수 94만회',
#  '조회수 33만회',
#  '조회수 114만회',
#  '조회수 168만회',
#  '조회수 350만회',
#  '조회수 157만회',
#  '조회수 422만회',
#  '조회수 548만회',
#  '조회수 265만회',
#  '조회수 74만회',
#  '조회수 334만회',
#  '조회수 247만회',
#  '조회수 353만회',
#  '조회수 844만회',
#  '조회수 66만회',
#  '조회수 572만회',
#  '조회수 231만회',
#  '조회수 96만회',
#  '조회수 33만회',
#  '조회수 52만회',
#  '조회수 50만회',
#  '조회수 65만회',
#  '조회수 272만회']

# %%
def nview(text):
    view = text.replace('조회수','')
    num = float(view[:-2])
    danwee = view[-2:]
    if danwee == '만회':
        return int(num*10000)
    else:
        int(num*1000)
        
view_number_type_list = []
for view in view_num_list:
    view_number_type_list.append(nview(view))

view_number_type_list
# Out:
# [550000,
#  250000,
#  500000,
#  340000,
#  260000,
#  500000,
#  470000,
#  1510000,
#  460000,
#  990000,
#  250000,
#  700000,
#  1250000,
#  480000,
#  290000,
#  790000,
#  560000,
#  1230000,
#  670000,
#  400000,
#  480000,
#  250000,
#  420000,
#  270000,
#  800000,
#  280000,
#  900000,
#  1840000,
#  660000,
#  290000,
#  240000,
#  550000,
#  590000,
#  1430000,
#  410000,
#  340000,
#  2030000,
#  410000,
#  1670000,
#  740000,
#  1960000,
#  1030000,
#  1220000,
#  310000,
#  530000,
#  610000,
#  290000,
#  1440000,
#  630000,
#  1870000,
#  200000,
#  3190000,
#  310000,
#  190000,
#  1910000,
#  510000,
#  450000,
#  1790000,
#  310000,
#  1230000,
#  1460000,
#  350000,
#  560000,
#  2390000,
#  780000,
#  860000,
#  660000,
#  2290000,
#  820000,
#  1240000,
#  1050000,
#  150000,
#  1320000,
#  620000,
#  410000,
#  510000,
#  240000,
#  510000,
#  500000,
#  5040000,
#  1240000,
#  540000,
#  1000000,
#  1340000,
#  1750000,
#  190000,
#  890000,
#  200000,
#  1190000,
#  520000,
#  100000,
#  1820000,
#  530000,
#  1570000,
#  460000,
#  260000,
#  490000,
#  930000,
#  180000,
#  1690000,
#  1090000,
#  73000,
#  300000,
#  400000,
#  980000,
#  4830000,
#  1860000,
#  1000000,
#  1230000,
#  400000,
#  1050000,
#  3470000,
#  900000,
#  230000,
#  1430000,
#  560000,
#  5290000,
#  1990000,
#  940000,
#  170000,
#  880000,
#  800000,
#  170000,
#  720000,
#  1240000,
#  1830000,
#  1790000,
#  1370000,
#  5470000,
#  380000,
#  4720000,
#  400000,
#  330000,
#  1470000,
#  5300000,
#  2290000,
#  360000,
#  800000,
#  1150000,
#  1110000,
#  220000,
#  760000,
#  2340000,
#  340000,
#  560000,
#  550000,
#  2090000,
#  480000,
#  2330000,
#  300000,
#  1850000,
#  2000000,
#  1820000,
#  220000,
#  710000,
#  3500000,
#  1320000,
#  650000,
#  220000,
#  1110000,
#  3830000,
#  1760000,
#  810000,
#  580000,
#  730000,
#  110000,
#  2320000,
#  1090000,
#  930000,
#  3330000,
#  2330000,
#  330000,
#  2080000,
#  1130000,
#  660000,
#  3090000,
#  4110000,
#  800000,
#  2630000,
#  590000,
#  970000,
#  570000,
#  2250000,
#  6090000,
#  1360000,
#  2820000,
#  1930000,
#  1030000,
#  930000,
#  940000,
#  330000,
#  1140000,
#  1680000,
#  3500000,
#  1570000,
#  4220000,
#  5480000,
#  2650000,
#  740000,
#  3340000,
#  2470000,
#  3530000,
#  8440000,
#  660000,
#  5720000,
#  2310000,
#  960000,
#  330000,
#  520000,
#  500000,
#  650000,
#  2720000]

# %%
dict_youtube = {'title':title_list, 'video_time':video_time_seperate_list, 'view_num':view_number_type_list}

import pandas as pd
youtube = pd.DataFrame(dict_youtube)
youtube.head()
# Out:
#                                                title  video_time  view_num
# 0            라면으로 만드는 비빔면 Bibimmyun Made From Ramyun         606    550000
# 1                                    초간단 '고추기름' 만들기!         308    250000
# 2                       뽀오얀 국물이 제대로~ 더위 나기 보양식 '닭곰탕'         668    500000
# 3                                        이런 카레가 있었어?         593    340000
# 4  고기와 싸먹으면 정~말 맛있는 파프리카 무침! 입안에서 톡!! Bursts in Y...         741    260000

# %%
youtube.to_excel("백종원.xlsx")
